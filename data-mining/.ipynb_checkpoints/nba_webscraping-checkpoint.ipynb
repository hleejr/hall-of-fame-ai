# %%
# imports used for webscraping
import sys
import requests
import pandas
import numpy
from bs4 import BeautifulSoup

# %%
'''
Here the response content is being tested before beginning data mining process. The chosen test subject is the html for Lebron Jame's profile on Basketball Reference. The first line of code creates the request to that html page and the next line uses beautiful soup to transform the data into a format that can be easily manipulate. Next, Lebron's name is retrieved from the html and the next two lines filter the response for tables holding his career totals for in the regular season and the playoffs. The next compound statement focuses on retrieving information about any awards Lebron has received throughout his career. After locating the html by id, the information is transformed and stored. Moving to the next block of code, the parsed html data is manipulated to retrieve the pieces of text that are important for collection purposes. First, the names of each stat is retrieved and stored. Then, the unneeded columns are sliced from the new list of stat names.

The third compound statement is where the fun really begins and the actually data mining gets underway. The table containing Lebron's regular season totals is found and filter, creating a new list from every row that is present in the table. Each row represents another season Lebron participated in. These list are each stored within a variable to house all of lebron's seasons in one place. This process is then repeated for his playoff statistics before turning the data into dictionaries to make it more readable.
'''

lebron_page = requests.get("https://www.basketball-reference.com/players/j/jamesle01.html")
lebron_soup = BeautifulSoup(lebron_page.content, 'html.parser')
lebron_name = lebron_soup.body.find(id='meta').find("h1").find("span").text
lebron_totals = lebron_soup.body.find(id="totals")
lebron_playoffs_totals = lebron_soup.body.find(id="playoffs_totals")

html_awards = lebron_soup.body.find_all(id='bling')
lebron_awards = []
if html_awards:
    award = html_awards[0].find_all('a')
    for i in range(len(award)):
        lebron_awards.append(award[i].text)

table_columns = lebron_totals.find_all("th")
stat_columns = []
for stat in table_columns:
    if stat.text == "\xa0":
        continue
    stat_columns.append(stat.text)
stat_names = stat_columns[0:31]

lebron_reg = []
reg_table = lebron_totals.find("tbody").find_all("tr")
for row in reg_table:
    season=[]
    season.append(row.find("th").text)
    for stat in row.find_all("td"):
        if stat.text == "":
            continue
        season.append(stat.text)
    lebron_reg.append(season)
    
lebron_po = []
po_table = lebron_playoffs_totals.find("tbody").find_all("tr")
for row in po_table:
    season=[]
    season.append(row.find("th").text)
    for stat in row.find_all("td"):
        if stat.text == "":
            continue
        season.append(stat.text)
    lebron_po.append(season)
    

lebron_stats = {}
for season in lebron_reg:
    lebron_stats[season[0]] = {}
    for stat in enumerate(season):
        index, data = stat
        lebron_stats[season[0]][stat_names[index]] = data
        
for key in lebron_stats:
    del lebron_stats[key]["Season"]
    
lebron_po_stats = {}
for season in lebron_po:
    lebron_po_stats[season[0]] = {}
    for stat in enumerate(season):
        index, data = stat
        lebron_po_stats[season[0]][stat_names[index]] = data
        
for key in lebron_po_stats:
    del lebron_po_stats[key]["Season"]

# %%
# %%script false --no-raise-error
